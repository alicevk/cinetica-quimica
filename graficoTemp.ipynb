# %%
# -------------------------------- Importações ------------------------------- #
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

# %%
# ---------------------------- Importando os dados --------------------------- #
dfConc = pd.read_csv('dados/Temp/T-Num=300.csv', header=None)

dfConc
# Out:
#            0            1
# 0        0.0     0.000000
# 1        1.0   943.358785
# 2        2.0   987.505718
# 3        3.0   987.653367
# 4        4.0   987.653861
# ...      ...          ...
# 6122  6122.0  1966.532585
# 6123  6123.0  1968.786149
# 6124  6124.0  1968.800975
# 6125  6125.0  1968.801072
# 6126  6126.0  1968.801073
#
# [6127 rows x 2 columns]

# %%
# ------------------------- Igualando as porcentagens ------------------------ #
eixo_x = np.array(dfConc[0], dtype=np.float128) * 1e-4

eixo_y = np.array(dfConc[1], dtype=np.float128)

# %%
# ---------------------- Plotando os dados da simulação ---------------------- #
plt.figure(figsize=(8,5))

plt.title('Variação na temperatura do sistema')

plt.xlabel(r'Tempo (Frames $\times \, 10^{-4}$)')
plt.ylabel('Temperatura (u.a.)')

plt.plot(eixo_x, eixo_y, color='red')

plt.grid()
plt.show()
